# %%
from PIL import image
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-7892611e7a30> in <module>
# ----> 1 from PIL import image
#
# ImportError: cannot import name 'image' from 'PIL' (c:\users\isgm204\appdata\local\programs\python\python37\lib\site-packages\PIL\__init__.py)

# %%
import PIL

# %%
from PIL import Image

# %%
mac = Image.open('neko1.png')

# %%
type(mac)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=760x506 at 0x19FEF7734A8>

# %%
mac.show()

# %%
mac.size
# Out:
# (760, 506)

# %%
mac.filename
# Out:
# 'neko1.png'

# %%
mac.format_description
# Out:
# 'JPEG (ISO 10918)'

# %%
mac.crop()
# Out:
# <PIL.Image.Image image mode=RGB size=760x506 at 0x19FEF83B2E8>

# %%
mac.crop((0,0,100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x19FEF814A90>

# %%
pencils = Image.open('neko1.png')

# %%
pencils
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=760x506 at 0x19FEF83B9E8>

# %%
neko2 = Image.open('neko2.jpg')

# %%
neko2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=693x520 at 0x19FEF832828>

# %%
neko2.size
# Out:
# (693, 520)

# %%
x =0
y=0
w=1950/3
h=1300/10

# %%
neko2.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=650x130 at 0x19FEF84CCF8>

# %%
neko2.size
# Out:
# (693, 520)

# %%
neko2.resize((30,50))
# Out:
# <PIL.Image.Image image mode=RGB size=30x50 at 0x19FEF85B668>

# %%
neko2.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGB size=693x520 at 0x19FEF85B860>

# %%
neko2
